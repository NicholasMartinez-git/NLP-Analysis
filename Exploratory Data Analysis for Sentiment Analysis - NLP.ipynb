# %%
# We'll start by reading in the corpus, which preserves word order
import pandas as pd

data = pd.read_pickle('corpus_sentiment_analysis.pkl')
data
# Out:
#                                            transcript
# 0   Excellent service great experience. Enjoyed ap...
# 1   First time here and it was amazing. The food w...
# 2   Josh our waiter was the best part of the night...
# 3   Very loud, then we ordered what was on the men...
# 4   Food was delicious. Service was wonderful. One...
# 5   I ordered a chicken panini and it was not good...
# 6   Outstanding service. Great atmosphere and terr...
# 7   Celebrated My friend’s birthday and the two of...
# 8   Went for lunch. Increased prices and no lunch ...
# 9   Birthday dinner for our daughter. Great food; ...
# 10  Food and service was great! The restaurant bui...
# 11  Very good food. Nice portion size. A bit noisy...
# 12  Amazing food & service. The Chicken Alfredo an...
# 13                                       Mother’s Day
# 14  Excellent Italian cuisine, superb service! Bus...
# 15  I had a reservation and was quickly seated. Ou...
# ...

# %%
data_clean = pd.read_pickle('data_clean_sentiment_analysis.pkl')
data_clean
# Out:
#                                            transcript
# 0   excellent service great experience enjoyed app...
# 1   first time here and it was amazing the food wa...
# 2   josh our waiter was the best part of the night...
# 3   very loud then we ordered what was on the menu...
# 4   food was delicious service was wonderful one o...
# 5   i ordered a chicken panini and it was not good...
# 6   outstanding service great atmosphere and terri...
# 7   celebrated my friends birthday and the two of ...
# 8   went for lunch increased prices and no lunch s...
# 9   birthday dinner for our daughter great food in...
# 10  food and service was great the restaurant buil...
# 11  very good food nice portion size a bit noisy b...
# 12  amazing food  service the chicken alfredo and ...
# 13                                        mothers day
# 14  excellent italian cuisine superb service busy ...
# 15  i had a reservation and was quickly seated our...
# ...

# %%
# Create quick lambda functions to find the polarity and subjectivity of each routine
# Terminal / Anaconda Navigator: conda install -c conda-forge textblob
from textblob import TextBlob

pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity

data['polarity'] = data['transcript'].apply(pol)
data['subjectivity'] = data['transcript'].apply(sub)
data
# Out:
#                                            transcript  polarity  subjectivity
# 0   Excellent service great experience. Enjoyed ap...  0.766667      0.816667
# 1   First time here and it was amazing. The food w...  0.389286      0.526190
# 2   Josh our waiter was the best part of the night...  0.750000      0.537500
# 3   Very loud, then we ordered what was on the men...  0.046373      0.452941
# 4   Food was delicious. Service was wonderful. One...  0.833333      1.000000
# 5   I ordered a chicken panini and it was not good... -0.243750      0.541667
# 6   Outstanding service. Great atmosphere and terr...  0.516667      0.737500
# 7   Celebrated My friend’s birthday and the two of...  0.400000      0.687500
# 8   Went for lunch. Increased prices and no lunch ... -0.016667      0.645238
# 9   Birthday dinner for our daughter. Great food; ...  0.775000      0.750000
# 10  Food and service was great! The restaurant bui... -0.084167      0.453889
# ...

# %%
data_clean['polarity'] = data_clean['transcript'].apply(pol)
data_clean['subjectivity'] = data_clean['transcript'].apply(sub)
data_clean
# Out:
#                                            transcript  polarity  subjectivity
# 0   excellent service great experience enjoyed app...  0.766667      0.816667
# 1   first time here and it was amazing the food wa...  0.360714      0.526190
# 2   josh our waiter was the best part of the night...  0.750000      0.537500
# 3   very loud then we ordered what was on the menu...  0.039020      0.452941
# 4   food was delicious service was wonderful one o...  0.833333      1.000000
# 5   i ordered a chicken panini and it was not good... -0.243750      0.541667
# 6   outstanding service great atmosphere and terri...  0.516667      0.737500
# 7   celebrated my friends birthday and the two of ...  0.400000      0.687500
# 8   went for lunch increased prices and no lunch s... -0.016667      0.645238
# 9   birthday dinner for our daughter great food in...  0.733333      0.750000
# 10  food and service was great the restaurant buil... -0.104167      0.453889
# ...

# %%
# Let's plot the results
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]

for index, webpage in enumerate(data.index):
    x = data.polarity.loc[index]
    y = data.subjectivity.loc[index]
    plt.scatter(x, y, color='blue')
    plt.xlim(-1, 1.2) 
    
plt.title('Sentiment Analysis', fontsize=20)
plt.xlabel('<-- Negative -------- Positive -->', fontsize=15)
plt.ylabel('<-- Facts -------- Opinions -->', fontsize=15)

plt.show()

# %%
# Let's plot the results
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]

for index, webpage in enumerate(data_clean.index):
    x = data_clean.polarity.loc[index]
    y = data_clean.subjectivity.loc[index]
    plt.scatter(x, y, color='blue')
    plt.xlim(-1, 1.2) 
    
plt.title('Sentiment Analysis', fontsize=20)
plt.xlabel('<-- Negative -------- Positive -->', fontsize=15)
plt.ylabel('<-- Facts -------- Opinions -->', fontsize=15)

plt.show()
